# %%
import torch
print("CUDA Available:", torch.cuda.is_available())

if torch.cuda.is_available():
  print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA Available: True
# GPU: Tesla T4

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2
import os

# %%
# !pip install -q ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n-seg.pt")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

print(os.listdir("/content/drive/MyDrive"))
# Out:
# ['IMG-20250204-WA0002.jpg', '20230802023.pdf', 'A6.pdf', 'Adhaar card (1).pdf', 'DOC-20240909-WA0004..pdf', 'Adhaar card.pdf', 'Certificate_Samriddhi Pathak .pdf', 'IMG_20250107_222518 (1).jpg', 'IMG_20250107_222518.jpg', 'IMG-20250430-WA0008.jpg', 'offer_letter.pdf', 'intership_form.pdf', 'adhaar card.pdf', 'Colab Notebooks', 'bdae 20230802023.pdf', 'Untitled form.gform', 'appsheet', 'certificate_20251572706052.pdf', 'CT08DL700 (1).pdf', '20230802023 Samriddhi Pathak.pdf', 'Screenshot_2026-03-05-12-53-02-76_ec576d6a4b63b6521ff16f5575cc4da0.jpg', 'Coursera K8OSGIQH524Y.pdf', 'ID card 01 Feb 2025.pdf', 'ID card 09 Nov 2024.pdf', 'expenses.gsheet', 'Age Calculator.gsheet', 'Servey.gsheet', 'TODO .gsheet', 'Untitled spreadsheet (1).gform', 'Untitled spreadsheet.gform', 'College Feedback survey (2).gform', 'College Feedback survey (1).gform', 'College Feedback survey.gsheet', 'College Feedback survey.gform', 'BPA.gsheet', 'Samriddhi_Resume (1) (1).pdf', 'Samriddhi_Resume (1).pdf', 'Offer
# ...

# %%
import os

print(os.listdir("/content/drive/MyDrive/tomato_project"))
# Out:
# ['archive', 'yolo_dataset']

# %%
import os

print(os.listdir("/content/drive/MyDrive/tomato_project/yolo_dataset"))
# Out:
# ['images', 'labels', 'data.yaml']

# %%
with open("/content/drive/MyDrive/tomato_project/yolo_dataset/data.yaml", "r") as f:
    print(f.read())
# Out:
# path: /content/drive/MyDrive/tomato_project/yolo_dataset
#
# train: images/train
# val: images/val
# test: images/test
#
# names:
#   0: unripe
#   1: ripe

# %%
import os

print(os.path.exists("/content/drive/MyDrive/tomato_project/yolo_dataset/data.yaml"))
print(os.path.exists("/content/drive/MyDrive/tomato_project/yolo_dataset/images/train"))
print(os.path.exists("/content/drive/MyDrive/tomato_project/yolo_dataset/labels/train"))
# Out:
# True
# True
# True

# %%
from ultralytics import YOLO

model = YOLO("yolov8n-seg.pt")

results = model.train(
    data="/content/drive/MyDrive/tomato_project/yolo_dataset/data.yaml",
    epochs=30,
    imgsz=640,
    batch=8,
    project="/content/drive/MyDrive/tomato_project/training",
    name="tomato_segmentation",
    workers=2,
    seed=42
)
# Out:
# Ultralytics 8.4.93 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
